# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsonyasonya/cuda-lab/blob/main/Image_Convolution_Filter_Implementation_with_CUDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue May 26 10:30:04 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/lsawicki-cdv/course-accelerating-apps-nvidia-cuda.git
# %cd /content/course-accelerating-apps-nvidia-cuda/templates/
# !cp convolution_filter.cu my_convolution.cu
# Out:
# Cloning into 'course-accelerating-apps-nvidia-cuda'...
# remote: Enumerating objects: 13659, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 13659 (delta 62), reused 86 (delta 30), pack-reused 13532 (from 5)
# Receiving objects: 100% (13659/13659), 140.07 MiB | 27.72 MiB/s, done.
# Resolving deltas: 100% (2287/2287), done.
# /content/course-accelerating-apps-nvidia-cuda/templates

# %%
# !nvcc my_convolution.cu -o my_convolution
# !./my_convolution
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ...
#    CUDA Convolution Lab - Performance Evaluation
# ...
# Image Size: 2048x2048 | Filter Width: 5
#
# [-] CPU sequential execution completed.
# [-] GPU Naive execution completed.
# SUCCESS! CPU and GPU results match using gaussianBlur5x5!
# [-] GPU Constant Memory execution completed.
# SUCCESS! Constant Memory results match using gaussianBlur5x5!
# [-] GPU Shared Memory execution completed.
# SUCCESS! Shared Memory results match using gaussianBlur5x5!
# ...
#    PERFORMANCE SUMMARY (Time in Milliseconds)
# ...
#  CPU Sequential      :   919.9516 ms
#  GPU Naive           :     1.1922 ms  (Speedup: x771.65)
#  GPU Constant Memory :     0.5509 ms  (Speedup: x1669.87)
#  GPU Shared Memory   :     0.4453 ms  (Speedup: x2066.01)
# ...

# %%
# !cp my_convolution.cu part1_backup.cu
