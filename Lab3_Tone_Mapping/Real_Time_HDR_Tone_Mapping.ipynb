# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsonyasonya/cuda-lab/blob/main/Real_Time_HDR_Tone_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !apt-get update
# !apt-get install -y build-essential cmake libopencv-dev

# %%
# !git clone https://github.com/lsawicki-cdv/course-accelerating-apps-nvidia-cuda.git

# %%
# %cd /content/course-accelerating-apps-nvidia-cuda/templates/cuda-webcam-filter
# !mkdir -p build

# %%
# %cd build
# !cmake ..
# !make -j$(nproc)

# %%
# !./cuda-webcam-filter --input=image --path=/content/beer.jpg --filter=hdr --exposure=2.0 --gamma=1.5 --saturation=1.5

# %%
# !./cuda-webcam-filter --input=image --path=/content/forest.jpg --filter=hdr --exposure=5.0 --gamma=2.0 --saturation=1.5
